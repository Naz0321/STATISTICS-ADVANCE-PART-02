# %% [markdown]
# ** THEORY QUESTION **
#
#
# **Q1.What is hypothesis testing in statistics**
#
# ANS.Hypothesis testing in statistics is a formal method used to make decisions or inferences about population parameters based on sample data. It helps determine whether the observed data provides enough evidence to support a specific claim or hypothesis about the population.
#
#
# ---
#
# 🔍 Key Concepts in Hypothesis Testing:
#
# 1. Null Hypothesis ():
#
# The default or original claim.
#
# Assumes no effect or no difference.
#
# Example: “The mean weight of apples is 150g.”
#
#
#
# 2. Alternative Hypothesis ( or ):
#
# The competing claim we want to test.
#
# Suggests there is an effect or difference.
#
# Example: “The mean weight of apples is not 150g.”
#
#
#
# 3. Test Statistic:
#
# A numerical value calculated from the sample data (e.g., Z-score, t-score).
#
# It quantifies how far the sample result is from what we’d expect under .
#
#
#
# 4. P-value:
#
# The probability of observing the sample result (or more extreme) if  is true.
#
# A small p-value indicates that the observed result is unlikely under .
#
#
#
# 5. Significance Level ():
#
# The threshold for deciding whether to reject .
#
# Common choices: 0.05 (5%), 0.01 (1%).
#
#
#
# 6. Decision Rule:
#
# If p-value ≤  → Reject .
#
# If p-value >  → Fail to reject .
#
#
#
# 7. Types of Errors:
#
# Type I Error: Rejecting  when it is actually true (false positive).
#
# Type II Error: Failing to reject  when  is true (false negative).
#
#
#
#
# **Q2.What is the null hypothesis, and how does it differ from the alternative hypothesis?**
#
# ANS. In statistics, hypothesis testing is a method used to make inferences or draw conclusions about a population based on sample data. Two key components of this process are the null hypothesis and the alternative hypothesis:
#
#
# ---
#
# ✅ Null Hypothesis (H₀):
#
# It is the default or initial assumption.
#
# States that there is no effect, no difference, or no relationship.
#
# It assumes that any observed effect in the sample data is due to random chance.
#
#
# Examples:
#
# A new drug has no effect compared to the standard drug:
#
# > H₀: μ_new = μ_standard
#
#
#
# A coin is fair:
#
# > H₀: p = 0.5
#
#
#
#
#
# ---
#
# 🔁 Alternative Hypothesis (H₁ or Ha):
#
# It is what the researcher aims to prove.
#
# Suggests that there is an effect, difference, or relationship.
#
# If evidence strongly contradicts the null hypothesis, the alternative is considered more likely.
#
#
# Examples:
#
# The new drug is more effective:
#
# > H₁: μ_new > μ_standard
#
#
#
# The coin is not fair:
#
# > H₁: p ≠ 0.5
#
#
#
#
#
# ---
#
# 🔍 Key Differences:
#
# Feature	Null Hypothesis (H₀)	Alternative Hypothesis (H₁ or Ha)
#
# Assumption	No change or effect	There is a change or effect
# Research Goal	Tested to be rejected	Goal is to support it
# Evidence Requirement	Needs strong evidence to reject	Becomes accepted if H₀ is rejected
# Symbol	H₀	H₁ or Ha
#
#
#
# ---
#
# 🧪 In Testing:
#
# You never prove the null hypothesis — you either:
#
# Fail to reject H₀ (not enough evidence),
#
# Or reject H₀ in favor of H₁ (enough evidence).
#
#
#
# **Q3.What is the significance level in hypothesis testing, and why is it important?**
#
#
# ANS. The significance level, often denoted by α (alpha), is the probability of rejecting the null hypothesis when it is actually true. In other words, it represents the risk of making a Type I error.
#
# Common Significance Levels:
#
# α = 0.05 (most common)
#
# α = 0.01
#
# α = 0.10
#
#
# For example, if α = 0.05, there's a 5% chance you'll incorrectly reject the null hypothesis when it's actually correct.
#
#
# ---
#
# Why Is It Important?
#
# 1. Controls Error Risk (Type I Error):
#
# It sets the threshold for how much evidence you require to reject the null hypothesis.
#
# Lower α = lower chance of false positives, but possibly higher chance of missing true effects (Type II error).
#
#
#
# 2. Guides Decision Making:
#
# Helps you decide whether your result is statistically significant.
#
# If your p-value ≤ α, you reject the null hypothesis.
#
#
#
# 3. Defines Confidence Level:
#
# A significance level of 0.05 corresponds to a 95% confidence level.
#
# This means you're 95% confident your results aren't due to random chance.
#
#
#
#
#
# ---
#
# Example:
#
# You're testing a new drug:
#
# Null hypothesis (H₀): The drug has no effect.
#
# You choose α = 0.05.
#
# If your test yields a p-value of 0.03, you reject H₀, because 0.03 < 0.05.
#
# You conclude the drug likely has an effect—with a 5% risk of being wrong.
#
#
#
# ---
#
# Summary:
#
# The significance level is a crucial part of hypothesis testing because it:
#
# Sets the bar for rejecting the null hypothesis.
#
# Balances the trade-off between detecting a real effect and avoiding false alarms.
#
# Ensures the scientific rigor and reproducibility of results.
#
#
# **Q4. What does a P-value represent in hypothesis testing?**
#
# ANS.In hypothesis testing, the P-value (or probability value) represents the probability of observing the sample results—or something more extreme— assuming that the null hypothesis (H₀) is true.
#
#
# ---
#
# 🔍 Key Interpretation:
#
# A small P-value (typically ≤ 0.05) indicates strong evidence against the null hypothesis, so you reject H₀.
#
# A large P-value (> 0.05) suggests weak evidence against the null hypothesis, so you fail to reject H₀.
#
#
#
# ---
#
# 🎯 Why is it important?
#
# The P-value helps determine:
#
# Whether the observed results are statistically significant.
#
# How compatible the data are with the null hypothesis.
#
#
#
# ---
#
# 📊 Example:
#
# Suppose you are testing whether a new drug is more effective than a placebo.
#
# Null hypothesis (H₀): The drug has no effect.
#
# Alternative hypothesis (H₁): The drug has a positive effect.
#
# After testing, you find a P-value of 0.03.
#
#
# 👉 Since 0.03 < 0.05, you reject the null hypothesis and conclude the drug likely has a real effect.
#
#
# ---
#
# Let me know if you'd like a visual or Python example to see how it's computed.
#
#
# ** Q5. How do you interpret the P-value in hypothesis testing?**
#
# ANS.In hypothesis testing, the P-value (or probability value) helps you determine the strength of evidence against the null hypothesis.
#
#
# ---
#
# 🔍 Definition:
#
# The P-value is the probability of observing a test statistic as extreme as, or more extreme than, the one observed — assuming the null hypothesis is true.
#
#
# ---
#
# ✅ Interpretation Guidelines:
#
# P-value	Interpretation	Decision (if α = 0.05)
#
# Low (≤ α)	Strong evidence against the null hypothesis	Reject the null hypothesis
# High (> α)	Weak evidence against the null hypothesis	Fail to reject the null hypothesis
#
#
# Where α (alpha) is the significance level (commonly 0.05 or 5%).
#
#
# ---
#
# 📌 Example:
#
# Suppose you’re testing if a new drug is more effective than the standard one.
#
# Null Hypothesis (H₀): The new drug is not more effective.
#
# P-value = 0.03: There is a 3% chance of observing such results if H₀ is true.
#
#
# Since 0.03 < 0.05, you reject H₀, suggesting the new drug may be more effective.
#
#
#
#
# ** Q5.How do you interpret the P-value in hypothesis testing?**
#
#
# ANS.In hypothesis testing, the P-value helps you determine the strength of the evidence against the null hypothesis . Here's how to interpret it:
#
#
# ---
#
# 🔍 Definition:
#
# The P-value is the probability of obtaining test results at least as extreme as the observed results, assuming the null hypothesis is true.
#
#
# ---
#
# 📊 Interpretation:
#
# Low P-value (typically ≤ 0.05):
#
# Strong evidence against the null hypothesis.
#
# Reject the null hypothesis.
#
# Your result is statistically significant.
#
#
# High P-value (> 0.05):
#
# Weak evidence against the null hypothesis.
#
# Fail to reject the null hypothesis.
#
# Your result is not statistically significant.
#
#
#
#
# ---
#
# 🧠 Example:
#
# Suppose you're testing a new drug and get a P-value of 0.02.
#
# This means: If the drug had no effect (i.e., null hypothesis is true), there's a 2% chance you would see results as extreme as the ones you observed.
#
# Since 0.02 < 0.05, you would reject the null hypothesis and conclude the drug likely has an effect.
#
#
#
# ---
#
# 🚨 Important Notes:
#
# A P-value is not the probability that the null hypothesis is true.
#
# It doesn’t tell you the size or importance of the effect.
#
# Always interpret it in the context of the significance level (α) (e.g., 0.05) and the study design.
#
#
#
# **Q6.What are Type 1 and Type 2 errors in hypothesis testing?**
#
#
# ANS.In hypothesis testing, Type I and Type II errors are two types of incorrect conclusions that can occur when making decisions based on sample data.
#
#
# ---
#
# ✅ Type I Error (False Positive)
#
# Definition: Rejecting the null hypothesis (H₀) when it is actually true.
#
# Example: Concluding that a new drug works better than the current one when it actually doesn't.
#
# Probability of Type I Error: Denoted by α (alpha), which is the significance level (commonly set at 0.05 or 5%).
#
#
# > Think of it as "detecting an effect when there is none."
#
#
#
#
# ---
#
# ✅ Type II Error (False Negative)
#
# Definition: Failing to reject the null hypothesis (H₀) when it is actually false.
#
# Example: Concluding that a new drug has no effect when it actually does.
#
# Probability of Type II Error: Denoted by β (beta).
#
# Power of the Test: Defined as 1 - β, which is the probability of correctly rejecting a false null hypothesis.
#
#
# > Think of it as "missing an effect when there is one."
#
#
#
# ** Q7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
#
#
# ANS. In hypothesis testing, the difference between a one-tailed and a two-tailed test lies in the direction of the effect you're testing for:
#
#
# ---
#
# 🔹 One-Tailed Test
#
# Tests for the possibility of the relationship in one direction only.
#
# You use it when your alternative hypothesis states that a parameter is greater than or less than a certain value.
#
#
# Example:
#
# H₀: μ = 50
#
# H₁: μ > 50 (right-tailed)
# or
#
# H₁: μ < 50 (left-tailed)
#
#
# ✅ Use when you only care about deviation in one direction.
#
#
# ---
#
# 🔹 Two-Tailed Test
#
# Tests for the possibility of the relationship in both directions.
#
# The alternative hypothesis states that the parameter is not equal to the value in the null hypothesis.
#
#
# Example:
#
# H₀: μ = 50
#
# H₁: μ ≠ 50
#
#
# ✅ Use when you care about any significant difference, whether higher or lower.
#
#
# ---
#
# 📊 Key Differences:
#
# Feature	One-Tailed Test	Two-Tailed Test
#
# Direction	One (greater or less)	Both (greater or less)
# Alternative Hypothesis	H₁: μ > μ₀ or μ < μ₀	H₁: μ ≠ μ₀
# Rejection Region	One side of distribution	Both sides of distribution
# Significance Level	Entire α in one tail	α split into two tails (α/2)
#
#
#
# ---
#
# 🧠 Tip:
#
# Use a one-tailed test only when you're confident that deviations can occur in only one direction. Otherwise, a two-tailed test is the safer and more conservative choice.
#
#
#
# ** Q8.What is the Z-test, and when is it used in hypothesis testing?**
#
#
# ANS. A Z-test is a type of hypothesis test used to determine whether there is a significant difference between sample and population means, or between two sample means, when the population variance is known or the sample size is large (n ≥ 30).
#
# It is based on the standard normal distribution (Z-distribution), which has a mean of 0 and a standard deviation of 1.
#
#
# ---
#
# When is the Z-test used?
#
# A Z-test is appropriate when the following conditions are met:
#
# 1. ✅ The sample size is large (n ≥ 30), or the population is normally distributed.
#
#
# 2. ✅ The population standard deviation (σ) is known.
#
#
# 3. ✅ The data is quantitative (interval or ratio scale).
#
#
#
#
# ---
#
# Types of Z-tests in hypothesis testing:
#
# 1. One-sample Z-test:
#
# Tests whether the sample mean differs from a known population mean.
#
#
#
#
# ** Q9.How do you calculate the Z-score, and what does it represent in hypothesis testing?**
#
#
# ANS.✅ How to Calculate the Z-score
#
# The Z-score (also called the standard score) tells you how many standard deviations a data point is from the population mean.
#
# The formula is:
#
# Z = \frac{X - \mu}{\sigma}
#
# Where:
#
#  = observed value (sample mean or data point)
#
#  = population mean
#
#  = population standard deviation
#
#
# In hypothesis testing for a sample mean, the formula is slightly modified:
#
# Z = \frac{\bar{X} - \mu_0}{\frac{\sigma}{\sqrt{n}}}
#
# Where:
#
#  = sample mean
#
#  = hypothesized population mean (from )
#
#  = population standard deviation
#
#  = sample size
#
#
#
# ---
#
# 🎯 What Does the Z-score Represent in Hypothesis Testing?
#
# The Z-score tells you how far your sample statistic (like the sample mean) is from the null hypothesis mean in units of standard error.
#
# In hypothesis testing:
#
# A large Z-score (positive or negative) means the sample mean is far from the hypothesized mean → potential evidence against .
#
# A small Z-score (close to 0) means the sample mean is close to the hypothesized mean → no strong evidence against .
#
#
# Use of Z-score:
#
# 1. Calculate the Z-score.
#
#
# 2. Compare it to a critical value (based on your chosen significance level, e.g., 1.96 for α = 0.05 in a two-tailed test).
#
#
# 3. Make a decision:
#
# If , reject .
#
# If , fail to reject .
#
#
#
#
# You can also use the Z-score to find the P-value, which quantifies the probability of observing a result as extreme as (or more extreme than) your sample, assuming  is true.
#
#
#
# ** Q10. What is the T-distribution, and when should it be used instead of the normal distribution?**
#
#
# ANS. The T-distribution, also known as Student's T-distribution, is a probability distribution that is symmetric and bell-shaped like the normal distribution but has heavier tails. This means it is more prone to producing values that fall far from its mean.
#
#
# ---
#
# 📘 Definition
#
# The T-distribution arises when estimating the mean of a normally distributed population in situations where the sample size is small and the population standard deviation is unknown.
#
#
# ---
#
# 🧠 Key Differences from the Normal Distribution
#
# Feature	Normal Distribution	T-Distribution
#
# Shape	Bell-shaped	Bell-shaped, heavier tails
# Used when...	σ (population std dev) known	σ unknown, sample std dev used
# Sample Size	Typically large (n > 30)	Typically small (n ≤ 30)
# Variability in tails	Less	More
# Degrees of Freedom	Not required	Required (n - 1)
#
#
#
# ---
#
# ✅ When to Use the T-Distribution
#
# Use the T-distribution instead of the normal distribution when:
#
# 1. The sample size is small (usually n ≤ 30),
#
#
# 2. The population standard deviation (σ) is unknown,
#
#
# 3. The data is approximately normally distributed.
#
#
#
#
# ---
#
# 📌 Example Scenario
#
# You want to test if the mean weight of a product is 500g. You only have a small sample (n = 10), and the population standard deviation is not known.
# ➡ Use a T-test and the T-distribution.
#
#
#
# ** Q11. What is the difference between a Z-test and a T-test?**
#
#
# ANS.The Z-test and T-test are both statistical tests used to determine whether there is a significant difference between sample and population means, or between two sample means. However, they differ in assumptions, usage, and distribution.
#
#
# ---
#
# 🔍 Key Differences Between Z-test and T-test
#
# Feature	Z-test	T-test
#
# Population Std Dev (σ)	Known	Unknown
# Sample Size (n)	Large (n > 30, typically)	Small (n ≤ 30, typically)
# Distribution Used	Standard Normal Distribution (Z-distribution)	Student's T-distribution
# Shape of Distribution	Fixed (standard normal, bell-shaped)	Flatter and wider tails (depends on degrees of freedom)
# Typical Applications	- Comparing sample mean to known population mean (σ known)<br>- Large sample hypothesis testing	- Comparing sample mean to population mean (σ unknown)<br>- Small sample comparisons
# Formula
#
#
#
# ---
#
# ✅ When to Use Which
#
# Use a Z-test when:
#
# The population standard deviation σ is known.
#
# The sample size is large (typically n > 30).
#
#
# Use a T-test when:
#
# The population standard deviation σ is unknown.
#
# The sample size is small (typically n ≤ 30).
#
# You're estimating the population mean from a sample.
#
#
#
#
# ---
#
# 🧠 Summary
#
# > Z-test assumes more known parameters and is suited for large samples.
# T-test is more flexible and commonly used when working with smaller samples and unknown standard deviations.
#
#
#
# ** Q12. What is the T-test, and how is it used in hypothesis testing?**
#
#
# ANS.
# The T-test is a statistical method used to determine if there is a significant difference between the means of two groups. It’s especially useful when dealing with small sample sizes and unknown population standard deviation.
#
#
# ---
#
# 🧪 When is the T-test used?
#
# Use a T-test when:
#
# The sample size is small (typically n < 30),
#
# The population standard deviation is unknown,
#
# The data is approximately normally distributed,
#
# You're comparing means (not proportions or variances).
#
#
#
# ---
#
# 📈 Types of T-tests
#
# Type	Use Case
#
# One-sample T-test	Compare the sample mean to a known value (e.g., population mean)
# Independent two-sample T-test	Compare the means of two independent groups
# Paired sample T-test	Compare the means of two related groups (e.g., before and after a treatment)
#
#
#
# ** Q13.What is the relationship between Z-test and T-test in hypothesis testing?**
#
#
# ANS.The Z-test and T-test are both statistical hypothesis tests used to determine whether there is a significant difference between sample data and a population, or between two sample groups. They are closely related and serve similar purposes, but are used under different conditions depending on the information available and sample size.
#
# 🔗 Relationship Between Z-test and T-test
#
# Aspect	Z-test	T-test
#
# Purpose	Test hypotheses about means or proportions when population parameters are known	Same purpose as Z-test, used when parameters are not known
# Population Standard Deviation (σ)	Known	Unknown (estimate using sample standard deviation s)
# Sample Size (n)	Typically large (n > 30)	Typically small (n ≤ 30), but can be used for any size if σ is unknown
# Distribution Used	Standard normal distribution (Z-distribution)	T-distribution (wider tails to account for uncertainty)
# Result	Z-score	T-score
#
#
#
# ---
#
# 📌 Summary of Their Relationship
#
# Both tests compare sample statistics to population values under the null hypothesis.
#
#
#
# **Q14.What is a confidence interval, and how is it used to interpret statistical results?**
#
#
# ANS.A confidence interval (CI) is a range of values, derived from a dataset, that is used to estimate an unknown population parameter (like a mean or proportion) with a certain level of confidence. It provides a measure of uncertainty around the sample statistic.
#
#
# ---
#
# 🔍 Definition:
#
# A confidence interval is typically written as:
#
# \text{Point Estimate} \pm \text{Margin of Error}
#
# Or:
#
# [\text{Lower bound}, \text{Upper bound}]
#
# For example, a 95% confidence interval for a population mean might be [48.5, 51.2]. This means we are 95% confident that the true population mean lies somewhere between 48.5 and 51.2.
#
#
# ---
#
# 🧠 Interpretation:
#
# Correct Interpretation: If we were to take many random samples and build a confidence interval from each, about 95% of those intervals would contain the true population parameter (for a 95% CI).
#
# Incorrect Interpretation: It is not correct to say there is a 95% probability that the population parameter lies within this specific interval (once calculated.
#
#
#
# **Q15.What is the margin of error, and how does it affect the confidence interval?**
#
#
# ANS.Margin of Error (MoE) is a key concept in statistics that reflects the amount of uncertainty or potential error in an estimate from a sample. It quantifies how much the sample result is likely to differ from the true population parameter.
#
#
# ---
#
# 🔹 Definition:
#
# The margin of error is the maximum expected difference between the true population value and a sample estimate, at a given confidence level (e.g., 95%).
#
# 🔹 Formula:
#
# \text{Margin of Error} = z^* \times \frac{\sigma}{\sqrt{n}}
#
#  = critical value from the standard normal distribution (depends on the confidence level)
#
#  = population standard deviation (or sample standard deviation  if  is unknown)
#
#  = sample size
#
#
#
# ---
#
# 🔹 How It Affects the Confidence Interval:
#
# The confidence interval (CI) is calculated as:
#
# \text{CI} = \text{Sample Mean} \pm \text{Margin of Error}
#
# So, the margin of error determines the width of the confidence interval:
#
# A larger margin of error → wider interval → more uncertainty
#
# A smaller margin of error → narrower interval → more precision.
#
#
#
# **Q16.How is Bayes' Theorem used in statistics, and what is its significance?**
#
#
# ANS.Bayes' Theorem is a fundamental concept in statistics and probability theory that allows us to update our beliefs about the probability of an event based on new evidence. It plays a critical role in statistical inference, decision-making, and machine learning.
#
#
# ---
#
# 🔷 Bayes’ Theorem Formula:
#
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
#
# Where:
#
#  = Posterior probability: probability of event  given  occurred
#
#  = Likelihood: probability of event  given  is true
#
#  = Prior probability: initial belief about event
#
#  = Marginal probability: total probability of event
#
#
#
# ---
#
# ✅ Uses of Bayes’ Theorem in Statistics:
#
# 1. Statistical Inference:
#
# Helps estimate the probability of a hypothesis given observed data.
#
# Core to Bayesian statistics, where parameters are treated as random variables with probability distributions.
#
#
#
# 2. Medical Diagnosis:
#
# Used to compute the probability that a patient has a disease given a positive test result.
#
# Adjusts for false positives and false negatives using prior prevalence rates.
#
#
#
# 3. Spam Filtering:
#
# Algorithms use Bayes’ Theorem to determine the likelihood an email is spam based on word occurrences.
#
#
#
# **Q17.What is the Chi-square distribution, and when is it used?**
#
#
# ANS.The Chi-square (χ²) distribution is a continuous probability distribution that is widely used in statistics, particularly for testing hypotheses about categorical data and variances. Here's a breakdown of what it is and when it's used:
#
#
# ---
#
# 🔹 What is the Chi-square Distribution?
#
# It is positively skewed (not symmetric), with the shape depending on the degrees of freedom (df).
#
# As the degrees of freedom increase, the distribution becomes more symmetric and approaches a normal distribution.
#
# It is defined only for non-negative values (x ≥ 0).
#
#
# Mathematically, the Chi-square distribution is the distribution of a sum of the squares of  independent standard normal random variables:
#
# \chi^2 = Z_1^2 + Z_2^2 + \dots + Z_k^2
#
# Where each  is a standard normal variable.
#
#
# ---
#
# 🔸 When is the Chi-square Distribution Used?
#
# 1. Goodness-of-Fit Test
#
# Purpose: To check whether a sample matches a theoretical distribution.
#
# Example: Testing if dice rolls are uniformly distributed.
#
#
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
#
# : observed frequency
#
# : expected frequency.
#
#
#
# **Q18.What is the Chi-square goodness of fit test, and how is it applied?**
#
#
# ANS.The Chi-square goodness of fit test is a statistical hypothesis test used to determine whether a sample data distribution matches a theoretical or expected distribution. It is particularly useful for categorical data.
#
#
# ---
#
# 🔍 Purpose:
#
# To test if the observed frequencies in categories significantly differ from expected frequencies under a certain theoretical distribution (e.g., uniform, binomial).
#
#
# ---
#
# 🧪 Hypotheses:
#
# Null hypothesis (H₀): The observed frequencies follow the expected distribution.
#
# Alternative hypothesis (H₁): The observed frequencies do not follow the expected distribution.
#
#
#
# ---
#
# 🧮 Chi-square Test Statistic Formula:
#
# \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
#
# Where:
#
#  = Observed frequency in category i
#
#  = Expected frequency in category i
#
# The summation is over all categories
#
#
#
# ---
#
# ✅ Conditions/Assumptions:
#
# 1. Data are counts (not percentages).
#
#
# 2. Categories are mutually exclusive.
#
#
# 3. Expected frequency.
#
#
#
# **Q19.What is the F-distribution, and when is it used in hypothesis testing?**
#
#
# ANS.The F-distribution is a probability distribution that arises frequently in the context of comparing variances. It is a right-skewed, continuous distribution that depends on two different degrees of freedom — one for the numerator and one for the denominator.
#
# Mathematically, if  and  are two independent chi-square distributed variables with degrees of freedom  and , then the random variable
#
# F = \frac{(X_1/d_1)}{(X_2/d_2)}
#
# follows an F-distribution with  and  degrees of freedom.
#
#
# ---
#
# When is the F-distribution used in hypothesis testing?
#
# The F-distribution is primarily used in these situations:
#
#
# ---
#
# 1. Testing Equality of Two Variances (F-test for variances)
#
# Null hypothesis (): The variances of two populations are equal.
#
# Alternative hypothesis (): The variances are not equal.
#
# Application: Used before performing a t-test (especially the two-sample t-test) to check the assumption of equal variances.
#
#
#
# ---
#
# 2. Analysis of Variance (ANOVA)
#
# Goal: Test whether three or more population means are equal.
#
# F-statistic: Compares the variance between group means to the variance within groups.
#
# Null hypothesis (): All group means are equal.
#
# Alternative hypothesis (): At least one group mean is different.
#
# Application: Common in experimental designs to analyze differences among group means.
#
#
#
# ---
#
# 3. Regression Analysis
#
# Use of F-distribution: To test the overall significance of a multiple regression model.
#
# Null hypothesis (): All regression coefficients (except intercept) are zero.
#
# Alternative hypothesis (): At least one predictor variable significantly contributes to the model.
#
#
#
# ---
#
# Key Properties
#
# Always positive (since variances and chi-square values are ≥ 0).
#
# The shape depends on degrees of freedom: skewed right for small d.f., becomes more symmetric for large d.f.
#
# Used in right-tailed tests, as we test for greater variability.
#
#
#
# **Q20.What is an ANOVA test, and what are its assumptions?**
#
#
# ANS.An ANOVA (Analysis of Variance) test is a statistical method used to determine whether there are significant differences between the means of three or more independent groups. It helps answer the question:
#
# > "Do at least one of these groups differ significantly in their average values?"
#
#
#
#
# ---
#
# 🔹 When is ANOVA used?
#
# Comparing test scores of students across multiple schools
#
# Comparing effectiveness of different treatments in clinical trials
#
# Any scenario where you compare 3 or more group means
#
#
# If only 2 groups are compared, a t-test is typically used.
#
#
# ---
#
# 🔹 Types of ANOVA:
#
# 1. One-Way ANOVA: Tests one independent variable (factor) with 3+ levels/groups.
#
#
# 2. Two-Way ANOVA: Tests two independent variables (factors) and possibly their interaction.
#
#
# 3. Repeated Measures ANOVA: Used when the same subjects are measured multiple times (within-subject design).
#
#
#
#
# ---
#
# 🔹 ANOVA Hypotheses:
#
# Null hypothesis (H₀): All group means are equal.
#
# Alternative hypothesis (H₁): At least one group mean is different.
#
#
#
# ---
#
# 🔹 Assumptions of ANOVA:
#
# To ensure the validity of the ANOVA results, these key assumptions must be met:
#
# 1. Independence of observations
#
# Samples are independent; data points in one group do not influence those in another.
#
#
#
# 2. Normality
#
# The data in each group should be approximately normally distributed.
#
# Especially important when sample sizes are small.
#
#
#
# 3. Homogeneity of variance (homoscedasticity)
#
# The variances across the groups should be approximately equal.
#
# Tested using Levene’s test or Bartlett’s test.
#
#
#
#
#
# ---
#
# 🔹 If assumptions are violated:
#
# Use non-parametric alternatives like the Kruskal-Wallis test (for one-way ANOVA).
#
# Or apply transformations to the data.
#
#
#
#
# **Q21.What are the different types of ANOVA tests?**
#
#
# ANS.ANOVA (Analysis of Variance) is a statistical method used to compare the means of different groups and determine whether at least one of the group means is significantly different from the others. There are several types of ANOVA tests, each suited for specific experimental designs. Here's a breakdown of the main types:
#
#
# ---
#
# 1. One-Way ANOVA
#
# Purpose: Compares the means of three or more independent groups based on one independent variable (factor).
#
# Example: Comparing test scores across three different teaching methods.
#
# Assumes:
#
# Independent groups
#
# Normal distribution
#
# Homogeneity of variance
#
#
#
#
# ---
#
# 2. Two-Way ANOVA (Factorial ANOVA)
#
# Purpose: Examines the effect of two independent variables (factors) on a dependent variable.
#
# Also tests for interaction between the two factors.
#
# Example: Studying the effect of diet (vegetarian, vegan, non-vegetarian) and exercise (yes/no) on weight loss.
#
# Variants:
#
# With replication (more than one observation per group)
#
# Without replication (only one observation per group)
#
#
#
#
# ---
#
# 3. Repeated Measures ANOVA
#
# Purpose: Used when the same subjects are measured multiple times (within-subject design).
#
# Example: Measuring blood pressure of patients at 3 different times (before, during, and after treatment).
#
# Accounts for the correlation between repeated observations.
#
#
#
# ---
#
# 4. Mixed-Design ANOVA (Split-Plot ANOVA)
#
# Purpose: Combines both within-subjects and between-subjects factors.
#
# Example: Measuring reaction time (within-subjects) across three trials for two groups (trained vs untrained).
#
#
#
# ---
#
# 5. MANOVA (Multivariate Analysis of Variance)
#
# Purpose: Extension of ANOVA when there are multiple dependent variables.
#
# Example: Studying how different diets affect both weight and cholesterol levels simultaneously.
#
#
#
# ---
#
# 6. ANCOVA (Analysis of Covariance)
#
# Purpose: Similar to ANOVA but includes one or more covariates to control for confounding variables.
#
# Example: Comparing test scores between teaching methods while controlling for prior knowledge (covariate).
#
#
#
# ---
#
# Summary Table:
#
# ANOVA Type	Factors	Repeated Measures	Multiple DVs	Covariates
#
# One-Way ANOVA	1	No	No	No
# Two-Way ANOVA	2	No	No	No
# Repeated Measures	1+	Yes	No	No
# Mixed ANOVA	1+	Mixed	No.
#
#
#
# **Q22.What is the F-test, and how does it relate to hypothesis testing?**
#
#
# ANS.The F-test is a statistical test that uses the F-distribution to compare variances, or to assess models in the context of hypothesis testing, especially in ANOVA (Analysis of Variance) and regression analysis.
#
#
# ---
#
# Purpose of the F-test:
#
# 1. Compare Two Population Variances
# Used to test if two populations have equal variances:
#
#
#
# H_0: \sigma_1^2 = \sigma_2^2 \quad \text{vs.} \quad H_1: \sigma_1^2 \ne \sigma_2^2
#
# F = \frac{s_1^2}{s_2^2}
#
# 2. ANOVA (Analysis of Variance)
# Used to test if three or more group means are equal. The F-statistic here is:
#
#
#
# F = \frac{\text{variance between groups}}{\text{variance within groups}}
#
# 3. Regression Analysis
# Tests the overall significance of a multiple regression model:
#
#
#
# H_0: \beta_1 = \beta_2 = \dots = \beta_k = 0
#
# H_1: \text{At least one } \beta_i \ne 0
#
#
# ---
#
# How It Relates to Hypothesis Testing:
#
# Null Hypothesis () typically states:
#
# "Variances are equal" (in variance tests),
#
# "All group means are equal" (in ANOVA),
#
# or "None of the predictors are useful" (in regression).
#
#
# Alternative Hypothesis () asserts that:
#
# Variances differ,
#
# At least one group mean differs,
#
# At least one predictor is significant.
#
#
# You calculate the F-statistic and compare it to the critical value from the F-distribution, or use the p-value.
#
#
#
# ---
#
# Key Assumptions:
#
# The data are normally distributed.
#
# Observations are independent.
#
# In ANOVA: Groups have equal variances (homoscedasticity).
#
#
#
# ---
#
# Example (ANOVA F-test):
#
# Suppose you're testing whether three diets affect weight loss differently:
#
# : All diet groups have the same mean weight loss.
#
# : At least one group mean differs.
#
#
# If the F-statistic is large and the p-value is small (e.g., < 0.05), you reject  — meaning the diets don’t have equal effects.

# %%
# ** PRACTICAL QUESTION **

# Q1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
interpret the results?

# ANS.

import math
from scipy.stats import norm

# Input values
population_mean = 100     # Known population mean (μ)
population_std = 15       # Known population standard deviation (σ)
sample_mean = 105         # Sample mean (x̄)
sample_size = 50          # Sample size (n)
alpha = 0.05              # Significance level

# Step 1: Calculate Z-score
standard_error = population_std / math.sqrt(sample_size)
z_score = (sample_mean - population_mean) / standard_error

# Step 2: Calculate p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Step 3: Compare p-value with alpha and interpret
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is NOT significantly different from the population mean.")
# Out:
# Object `results` not found.
# Z-score: 2.3570
# P-value: 0.0184
# Reject the null hypothesis: The sample mean is significantly different from the population mean.

# %%
# Q2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?

# ANS.


import numpy as np
from scipy import stats

# Step 1: Simulate random data (sample)
np.random.seed(42)  # For reproducibility
sample_size = 50
population_mean = 100
population_std = 15

# Generate sample from normal distribution
sample = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)

# Step 2: Hypothesis
# H0: μ = 100 (population mean)
# H1: μ ≠ 100 (two-tailed test)
hypothesized_mean = 100

# Step 3: Perform one-sample t-test
t_statistic, p_value = stats.ttest_1samp(sample, popmean=hypothesized_mean)

# Step 4: Output results
print(f"Sample mean: {np.mean(sample):.2f}")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpret result at alpha = 0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis (significant difference).")
else:
    print("Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample mean: 96.62
# T-statistic: -1.7076
# P-value: 0.0940
# Fail to reject the null hypothesis (no significant difference).

# %%
# Q3.Implement a one-sample Z-test using Python to compare the sample mean with the population mean?

# ANS.

import numpy as np
from scipy.stats import norm

# Sample data
sample = [105, 110, 98, 102, 100, 95, 108, 104, 101, 99]

# Known population parameters
population_mean = 100
population_std = 15  # population standard deviation
n = len(sample)

# Compute sample mean
sample_mean = np.mean(sample)

# Compute Z-statistic
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# Compute p-value (two-tailed)
p_value = 2 * (1 - norm.cdf(abs(z)))

# Output
print(f"Sample Mean: {sample_mean}")
print(f"Z-statistic: {z}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: no significant difference between sample and population mean.")
# Out:
# Sample Mean: 102.2
# Z-statistic: 0.4638007234913629
# P-value: 0.6427905249517658
# Fail to reject the null hypothesis: no significant difference between sample and population mean.

# %%
# Q4.Perform a two-tailed Z-test using Python and visualize the decision region on a plot?

# ANS.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mu = 100       # Population mean
sigma = 15     # Population standard deviation
n = 36         # Sample size
x_bar = 107    # Sample mean
alpha = 0.05   # Significance level

# Compute Z-statistic
z = (x_bar - mu) / (sigma / np.sqrt(n))

# Critical Z-values for two-tailed test
z_critical = norm.ppf(1 - alpha/2)

# Print results
print(f"Z-statistic: {z:.3f}")
print(f"Critical Z-values: ±{z_critical:.3f}")

# Visualization
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')

# Shade rejection regions
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.4, label='Rejection Region (Left)')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.4, label='Rejection Region (Right)')

# Shade acceptance region
plt.fill_between(x, y, where=(x > -z_critical) & (x < z_critical), color='green', alpha=0.2, label='Acceptance Region')

# Plot observed Z
plt.axvline(z, color='black', linestyle='--', label=f'Observed Z = {z:.2f}')

plt.title('Two-tailed Z-test Decision Regions')
plt.xlabel('Z-value')
plt.ylabel('Density')
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Z-statistic: 2.800
# Critical Z-values: ±1.960

# %%
# Q5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing?

# ANS.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(mu0=0, mu1=1, sigma=1, alpha=0.05, n=30):
    """
    Visualize Type I and Type II errors for hypothesis testing (Z-test).

    H0: μ = mu0
    H1: μ = mu1
    """
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical z for two-tailed test
    z_critical = norm.ppf(1 - alpha/2)

    # Critical values in terms of sample mean
    lower_crit = mu0 - z_critical * se
    upper_crit = mu0 + z_critical * se

    # x-axis range
    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)

    # Distributions under H0 and H1
    y0 = norm.pdf(x, mu0, se)  # H0 distribution
    y1 = norm.pdf(x, mu1, se)  # H1 distribution

    # Compute Type I error = alpha (already given)

    # Compute Type II error = probability of failing to reject H0 under H1
    beta = norm.cdf(upper_crit, mu1, se) - norm.cdf(lower_crit, mu1, se)

    # Plot distributions
    plt.figure(figsize=(10,6))
    plt.plot(x, y0, label='H0 Distribution (μ={})'.format(mu0), color='blue')
    plt.plot(x, y1, label='H1 Distribution (μ={})'.format(mu1), color='green')

    # Shade Type I error regions (alpha/2 each side)
    plt.fill_between(x, 0, y0, where=(x < lower_crit) | (x > upper_crit),
                     color='red', alpha=0.3, label='Type I Error (α)')

    # Shade Type II error region
    plt.fill_between(x, 0, y1, where=(x >= lower_crit) & (x <= upper_crit),
                     color='orange', alpha=0.3, label='Type II Error (β)')

    # Critical lines
    plt.axvline(lower_crit, color='black', linestyle='--', label='Critical Values')
    plt.axvline(upper_crit, color='black', linestyle='--')

    plt.title('Type I (α) and Type II (β) Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

    print(f"Critical values: {lower_crit:.3f}, {upper_crit:.3f}")
    print(f"Type I error (α): {alpha}")
    print(f"Type II error (β): {beta:.4f}")
    print(f"Power of the test (1-β): {1-beta:.4f}")

# Example usage
visualize_errors(mu0=0, mu1=1, sigma=1, alpha=0.05, n=30)
# Out:
# Critical values: -0.358, 0.358
# Type I error (α): 0.05
# Type II error (β): 0.0002
# Power of the test (1-β): 0.9998

# %%
# Q6.Write a Python program to perform an independent T-test and interpret the results?

# ANS.

import numpy as np
from scipy import stats

# Example Data: Two independent samples
group1 = [12, 15, 14, 10, 13, 14, 15]
group2 = [18, 20, 19, 17, 21, 20, 18]

# Perform Independent T-test (two-tailed)
t_stat, p_value = stats.ttest_ind(group1, group2)

# Print results
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# T-statistic: -6.6058
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two groups.

# %%
# Q7.Perform a paired sample T-test using Python and visualize the comparison results?

# ANS

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Generate sample data (Before and After)
np.random.seed(42)
before = np.random.normal(loc=50, scale=5, size=30)   # Before treatment
after = before + np.random.normal(loc=-2, scale=3, size=30)  # After treatment

# 2. Perform Paired Sample T-Test
t_stat, p_value = stats.ttest_rel(before, after)

print("Paired Sample T-Test Results:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 3. Visualize the Comparison
df = pd.DataFrame({'Before': before, 'After': after})

plt.figure(figsize=(8, 5))
sns.lineplot(data=df, palette="tab10", alpha=0.6, linewidth=1)
sns.boxplot(data=df, width=0.3, palette="Set2")
plt.title("Paired Sample Comparison (Before vs After)")
plt.ylabel("Values")
plt.show()
# Out:
# Paired Sample T-Test Results:
# T-statistic: 4.6344
# P-value: 0.0001

# %%
# Q8. Simulate data and perform both Z-test and T-test, then compare the results using Python?

# ANS.

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# 1. Simulate data
np.random.seed(42)
population_mean = 50
population_std = 10
sample_size = 30

# Generate sample data
sample = np.random.normal(population_mean, population_std, sample_size)

# Hypothesized mean
mu_0 = 52  # testing if population mean = 52

# 2. Z-test (one-sample)
sample_mean = np.mean(sample)
z_stat = (sample_mean - mu_0) / (population_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - stats.norm.cdf(abs(z_stat)))  # two-tailed

# 3. T-test (one-sample)
t_stat, p_value_t = stats.ttest_1samp(sample, mu_0)

# 4. Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-Test: Z = {z_stat:.4f}, p = {p_value_z:.4f}")
print(f"T-Test: t = {t_stat:.4f}, p = {p_value_t:.4f}")

# 5. Compare results
if p_value_z < 0.05:
    print("Z-test: Reject H0")
else:
    print("Z-test: Fail to Reject H0")

if p_value_t < 0.05:
    print("T-test: Reject H0")
else:
    print("T-test: Fail to Reject H0")

# 6. Visualization
x = np.linspace(mu_0 - 4*population_std, mu_0 + 4*population_std, 1000)
z_dist = stats.norm(mu_0, population_std / np.sqrt(sample_size))
t_dist = stats.t(df=sample_size-1, loc=mu_0, scale=np.std(sample, ddof=1)/np.sqrt(sample_size))

plt.figure(figsize=(10,6))
plt.plot(x, z_dist.pdf(x), label='Z Distribution', color='blue')
plt.plot(x, t_dist.pdf(x), label='T Distribution', color='green')
plt.axvline(sample_mean, color='red', linestyle='--', label=f'Sample Mean = {sample_mean:.2f}')
plt.title('Z-test vs T-test Distributions')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Sample Mean: 48.12
# Z-Test: Z = -2.1260, p = 0.0335
# T-Test: t = -2.3622, p = 0.0251
# Z-test: Reject H0
# T-test: Reject H0

# %%
# Q9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance?

# ANS.

import scipy.stats as st
import numpy as np

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
    data (list or array): Sample data
    confidence (float): Confidence level (default = 0.95)

    Returns:
    tuple: (lower_bound, upper_bound)
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = st.sem(data)  # Standard error of the mean

    # t critical value for given confidence and degrees of freedom
    t_critical = st.t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_critical * std_err
    return (mean - margin_of_error, mean + margin_of_error)

# Example usage:
sample_data = [12, 15, 14, 10, 13, 16, 14]
ci = confidence_interval(sample_data, confidence=0.95)
print(f"95% Confidence Interval: {ci}")
# Out:
# 95% Confidence Interval: (np.float64(11.589922964939948), np.float64(15.26721989220291))

# %%
# Q10. Write a Python program to calculate the margin of error for a given confidence level using sample data?

# ANS.

import numpy as np
import scipy.stats as st

def margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level.

    Parameters:
        data (list or array): Sample data
        confidence (float): Confidence level (default=0.95 for 95%)

    Returns:
        float: Margin of error
    """
    n = len(data)
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)  # sample standard deviation
    alpha = 1 - confidence

    # t-critical value for two-tailed test
    t_critical = st.t.ppf(1 - alpha/2, df=n-1)

    # Margin of error
    moe = t_critical * (std_dev / np.sqrt(n))
    return moe

# Example usage
sample_data = [12, 15, 14, 10, 13, 14, 16, 15, 14, 13]
confidence_level = 0.95

moe = margin_of_error(sample_data, confidence_level)
print(f"Margin of Error at {confidence_level*100}% confidence level: {moe:.4f}")
# Out:
# Margin of Error at 95.0% confidence level: 1.2252

# %%
# Q11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process?

# ANS.

def bayesian_inference(prior, likelihood, false_positive_rate):
    # Prior probabilities
    P_H = prior
    P_not_H = 1 - P_H

    # Likelihoods
    P_D_given_H = likelihood
    P_D_given_not_H = false_positive_rate

    # Evidence
    P_D = (P_D_given_H * P_H) + (P_D_given_not_H * P_not_H)

    # Posterior
    P_H_given_D = (P_D_given_H * P_H) / P_D
    return P_H_given_D

# Example values
prior = 0.01       # P(H)
likelihood = 0.99  # P(D|H)
false_positive = 0.05  # P(D|not H)

posterior = bayesian_inference(prior, likelihood, false_positive)
print(f"Posterior probability that the patient has the disease: {posterior:.4f}")
# Out:
# Posterior probability that the patient has the disease: 0.1667

# %%
# Q12. Perform a Chi-square test for independence between two categorical variables in Python?

# ANS.

import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Example data: Gender vs Preferred Product
data = {
    'Product_A': [30, 10],  # Male, Female
    'Product_B': [20, 20]
}

# Create contingency table (cross-tabulation)
contingency_table = pd.DataFrame(data, index=['Male', 'Female'])
print("Contingency Table:\n", contingency_table)

# Perform Chi-Square Test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print results
print(f"\nChi-Square Statistic: {chi2}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p}")
print("\nExpected Frequencies:\n", expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("\nReject the null hypothesis: There is a significant association between the variables.")
else:
    print("\nFail to reject the null hypothesis: No significant association between the variables.")
# Out:
# Contingency Table:
#          Product_A  Product_B
# Male           30         20
# Female         10         20
#
# Chi-Square Statistic: 4.32
# Degrees of Freedom: 1
# P-value: 0.03766692222862869
#
# Expected Frequencies:
#  [[25. 25.]
#  [15. 15.]]
#
# Reject the null hypothesis: There is a significant association between the variables.

# %%
# Q13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
data?

# ANS.

import numpy as np
import pandas as pd

# Example observed data (contingency table)
# Rows: categories of variable 1, Columns: categories of variable 2
observed = np.array([[50, 30],
                     [20, 100]])

# Convert to DataFrame for better readability
observed_df = pd.DataFrame(observed, columns=['Category1', 'Category2'], index=['Group1', 'Group2'])

# Calculate row totals, column totals, and grand total
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()

# Calculate expected frequencies
expected = np.outer(row_totals, col_totals) / grand_total

# Convert to DataFrame for readability
expected_df = pd.DataFrame(expected, columns=['Category1', 'Category2'], index=['Group1', 'Group2'])

# Print results
print("Observed Frequencies:")
print(observed_df)
print("\nExpected Frequencies:")
print(expected_df)
# Out:
# Observed Frequencies:
#         Category1  Category2
# Group1         50         30
# Group2         20        100
#
# Expected Frequencies:
#         Category1  Category2
# Group1       28.0       52.0
# Group2       42.0       78.0

# %%
# Q14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution?

# ANS.

import numpy as np
from scipy.stats import chisquare

# Observed data (example)
observed = np.array([50, 30, 20])

# Expected distribution (equal probabilities)
expected = np.array([1/3, 1/3, 1/3]) * sum(observed)

# Perform Chi-square goodness-of-fit test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed distribution is significantly different from the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed distribution fits the expected distribution.")
# Out:
# Chi-square Statistic: 14.0000
# P-value: 0.0009
# Reject the null hypothesis: The observed distribution is significantly different from the expected distribution.

# %%
# Q15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics?

# ANS.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Parameters
df = 4  # degrees of freedom
sample_size = 100000

# Simulate Chi-square distributed data
data = np.random.chisquare(df, size=sample_size)

# Plot histogram of simulated data
plt.figure(figsize=(10, 6))
plt.hist(data, bins=50, density=True, alpha=0.6, color='skyblue', label='Simulated Data')

# Overlay theoretical Chi-square PDF
x = np.linspace(0, np.max(data), 1000)
pdf = chi2.pdf(x, df)
plt.plot(x, pdf, 'r-', lw=2, label=f'Theoretical PDF (df={df})')

# Add labels and legend
plt.title(f'Chi-square Distribution (df={df})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Q16. Implement an F-test using Python to compare the variances of two random samples?

# ANS.

import numpy as np
from scipy.stats import f

# Generate two random samples
np.random.seed(42)  # for reproducibility
sample1 = np.random.normal(loc=50, scale=10, size=30)  # mean=50, std=10
sample2 = np.random.normal(loc=52, scale=15, size=35)  # mean=52, std=15

# Calculate sample variances
var1 = np.var(sample1, ddof=1)  # sample variance (ddof=1 for unbiased)
var2 = np.var(sample2, ddof=1)

# Compute F statistic
if var1 > var2:
    F = var1 / var2
    dfn = len(sample1) - 1  # degrees of freedom numerator
    dfd = len(sample2) - 1  # degrees of freedom denominator
else:
    F = var2 / var1
    dfn = len(sample2) - 1
    dfd = len(sample1) - 1

# Compute p-value (two-tailed)
p_value = 2 * min(f.cdf(F, dfn, dfd), 1 - f.cdf(F, dfn, dfd))

# Print results
print("Sample 1 Variance:", var1)
print("Sample 2 Variance:", var2)
print("F-statistic:", F)
print("Degrees of Freedom: ({}, {})".format(dfn, dfd))
print("p-value:", p_value)

# Decision
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in variances.")
# Out:
# Sample 1 Variance: 81.00115693656518
# Sample 2 Variance: 186.6402865021202
# F-statistic: 2.30416815710774
# Degrees of Freedom: (34, 29)
# p-value: 0.02437374400766612
# Reject the null hypothesis: Variances are significantly different.

# %%
# Q17. Write a Python program to perform an ANOVA test to compare means between multiple groups and
interpret the results?

# ANS.

import numpy as np
from scipy.stats import f_oneway

# Example data: three groups with different means
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=5, size=30)  # mean ~50
group2 = np.random.normal(loc=52, scale=5, size=30)  # mean ~52
group3 = np.random.normal(loc=55, scale=5, size=30)  # mean ~55

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(group1, group2, group3)

# Display results
print("ANOVA Test Results")
print("-------------------")
print(f"F-statistic: {f_statistic:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference among group means.")
# Out:
# Object `results` not found.
# ANOVA Test Results
# -------------------
# F-statistic: 12.3979
# p-value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
# Q18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results?

# ANS.

import numpy as np
import pandas as pd
from scipy.stats import f_oneway
import matplotlib.pyplot as plt
import seaborn as sns
# Simulated data for three groups
np.random.seed(42)  # for reproducibility
group_A = np.random.normal(loc=50, scale=5, size=30)
group_B = np.random.normal(loc=55, scale=5, size=30)
group_C = np.random.normal(loc=60, scale=5, size=30)
# One-way ANOVA test
f_stat, p_val = f_oneway(group_A, group_B, group_C)
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_val:.4f}")

if p_val < 0.05:
    print("Reject Null Hypothesis: There is a significant difference between group means.")
else:
    print("Fail to Reject Null Hypothesis: No significant difference between group means.")
    # Combine data into a DataFrame for plotting
data = pd.DataFrame({
    'Scores': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A']*30 + ['B']*30 + ['C']*30
})

# Boxplot to compare groups
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Scores', data=data, palette='Set2')
sns.swarmplot(x='Group', y='Scores', data=data, color='black', alpha=0.6)
plt.title('One-Way ANOVA: Group Comparisons')
plt.show()
# Out:
# F-statistic: 40.9756
# P-value: 0.0000
# Reject Null Hypothesis: There is a significant difference between group means.
# /tmp/ipython-input-25-979033273.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Scores', data=data, palette='Set2')

# %%
# Q19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA?

# ANS.

import numpy as np
import pandas as pd
from scipy.stats import shapiro, levene
from statsmodels.stats.stattools import durbin_watson
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

def check_anova_assumptions(data, group_col, value_col):
    """
    Check ANOVA assumptions: normality, independence, equal variances.

    Parameters:
    data : pandas DataFrame
        Dataset containing the groups and values.
    group_col : str
        Column name for the grouping variable.
    value_col : str
        Column name for the numeric values.

    Returns:
    None (prints results and plots)
    """
    # Fit ANOVA model to get residuals
    model = sm.OLS.from_formula(f"{value_col} ~ C({group_col})", data=data).fit()
    residuals = model.resid

    print("\n--- Checking Normality (Shapiro-Wilk Test) ---")
    stat, p = shapiro(residuals)
    print(f"Shapiro-Wilk Test: W={stat:.4f}, p-value={p:.4f}")
    if p > 0.05:
        print("Residuals seem normally distributed (p > 0.05).")
    else:
        print("Residuals may not be normally distributed (p ≤ 0.05).")

    # QQ Plot
    sm.qqplot(residuals, line='s')
    plt.title("QQ Plot of Residuals")
    plt.show()

    print("\n--- Checking Independence (Durbin-Watson) ---")
    dw = durbin_watson(residuals)
    print(f"Durbin-Watson statistic: {dw:.4f} (ideal ~2)")

    print("\n--- Checking Homogeneity of Variance (Levene's Test) ---")
    groups = [group[value_col].values for name, group in data.groupby(group_col)]
    stat, p = levene(*groups)
    print(f"Levene's Test: W={stat:.4f}, p-value={p:.4f}")
    if p > 0.05:
        print("Equal variances assumption seems valid (p > 0.05).")
    else:
        print("Variances may not be equal (p ≤ 0.05).")

    print("\n--- Visualization: Residuals Histogram ---")
    sns.histplot(residuals, kde=True)
    plt.title("Histogram of Residuals")
    plt.show()

# %%
# Q20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
results?

# ANS.

import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Object `results` not found.

# %%
# Q21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing?

# ANS.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Parameters for F-distribution
dfn = 5  # degrees of freedom numerator
dfd = 10 # degrees of freedom denominator

# Generate x values
x = np.linspace(0, 5, 500)

# Compute F-distribution PDF
pdf = f.pdf(x, dfn, dfd)

# Plot F-distribution
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, 'b-', label=f'F-distribution (dfn={dfn}, dfd={dfd})')
plt.title('F-distribution PDF')
plt.xlabel('F value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(alpha=0.3)

# Highlight critical region (α = 0.05, right tail)
alpha = 0.05
critical_value = f.ppf(1 - alpha, dfn, dfd)
plt.axvline(critical_value, color='r', linestyle='--', label=f'Critical Value = {critical_value:.2f}')
plt.fill_between(x, 0, pdf, where=(x > critical_value), color='red', alpha=0.3, label='Rejection Region')

plt.legend()
plt.show()

# %%
# Q22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means?

# ANS.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import f_oneway
import seaborn as sns

# -----------------------------
# Simulate sample data for 3 groups
# -----------------------------
np.random.seed(42)
group_A = np.random.normal(loc=50, scale=5, size=30)
group_B = np.random.normal(loc=52, scale=5, size=30)
group_C = np.random.normal(loc=55, scale=5, size=30)

# Combine into DataFrame
data = pd.DataFrame({
    'Score': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A']*30 + ['B']*30 + ['C']*30
})

# -----------------------------
# Perform One-Way ANOVA
# -----------------------------
f_stat, p_value = f_oneway(group_A, group_B, group_C)
print(f"F-statistic: {f_stat:.4f}, p-value: {p_value:.4f}")

# -----------------------------
# Visualization: Boxplot of groups
# -----------------------------
plt.figure(figsize=(8, 5))
sns.boxplot(x='Group', y='Score', data=data, palette='Set2')
sns.stripplot(x='Group', y='Score', data=data, color='black', alpha=0.5)

plt.title('Group Comparison using One-Way ANOVA')
plt.xlabel('Group')
plt.ylabel('Scores')
plt.grid(axis='y', alpha=0.3)
plt.show()
# Out:
# F-statistic: 12.3979, p-value: 0.0000
# /tmp/ipython-input-38-3219252615.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Score', data=data, palette='Set2')

# %%
# Q23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means?

# ANS.

import numpy as np
from scipy.stats import ttest_1samp, ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Simulate random data from normal distribution
# -----------------------------
np.random.seed(42)

# Population parameters
pop_mean = 50
pop_std = 5

# Sample data
sample1 = np.random.normal(loc=pop_mean, scale=pop_std, size=50)
sample2 = np.random.normal(loc=52, scale=5, size=50)  # slightly different mean

# -----------------------------
# Hypothesis Testing
# 1. One-sample t-test: Is sample1 mean = 50?
# -----------------------------
t_stat1, p_value1 = ttest_1samp(sample1, pop_mean)

print(f"One-Sample t-test:")
print(f"Sample Mean = {np.mean(sample1):.2f}")
print(f"t-statistic = {t_stat1:.4f}, p-value = {p_value1:.4f}\n")

# -----------------------------
# 2. Two-sample t-test: Are means of sample1 and sample2 equal?
# -----------------------------
t_stat2, p_value2 = ttest_ind(sample1, sample2)

print(f"Two-Sample t-test:")
print(f"Sample1 Mean = {np.mean(sample1):.2f}, Sample2 Mean = {np.mean(sample2):.2f}")
print(f"t-statistic = {t_stat2:.4f}, p-value = {p_value2:.4f}")

# -----------------------------
# Visualization
# -----------------------------
plt.figure(figsize=(8,5))
sns.histplot(sample1, color='blue', kde=True, label='Sample 1')
sns.histplot(sample2, color='orange', kde=True, label='Sample 2')
plt.axvline(np.mean(sample1), color='blue', linestyle='--', label=f'Mean1: {np.mean(sample1):.2f}')
plt.axvline(np.mean(sample2), color='orange', linestyle='--', label=f'Mean2: {np.mean(sample2):.2f}')
plt.title('Simulated Normal Distributions for Hypothesis Testing')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# One-Sample t-test:
# Sample Mean = 48.87
# t-statistic = -1.7076, p-value = 0.0940
#
# Two-Sample t-test:
# Sample1 Mean = 48.87, Sample2 Mean = 52.09
# t-statistic = -3.5559, p-value = 0.0006

# %%
# Q24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results?

# ANS.

import scipy.stats as stats

# Given values
n = 25
sample_var = 20
sigma0_sq = 16
alpha = 0.05

# Degrees of freedom
df = n - 1

# Chi-square statistic
chi2_stat = (df * sample_var) / sigma0_sq

# Critical values for two-tailed test
chi2_critical_low = stats.chi2.ppf(alpha/2, df)
chi2_critical_high = stats.chi2.ppf(1 - alpha/2, df)

# p-value
p_value = 2 * min(stats.chi2.cdf(chi2_stat, df), 1 - stats.chi2.cdf(chi2_stat, df))

chi2_stat, chi2_critical_low, chi2_critical_high, p_value
# Out:
# (30.0,
#  np.float64(12.401150217444435),
#  np.float64(39.36407702660391),
#  np.float64(0.3695035980478629))

# %%
# Q26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results?

# ANS.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Sample data
data1 = [10, 12, 9, 11, 14, 13, 10]
data2 = [8, 9, 6, 7, 10, 8, 9]

alpha = 0.05

# Sample sizes and variances
n1, n2 = len(data1), len(data2)
s1_sq, s2_sq = np.var(data1, ddof=1), np.var(data2, ddof=1)

# F-statistic
F = s1_sq / s2_sq

# Degrees of freedom
df1, df2 = n1 - 1, n2 - 1

# Critical values
F_crit_low = stats.f.ppf(alpha/2, df1, df2)
F_crit_high = stats.f.ppf(1 - alpha/2, df1, df2)

# p-value (two-tailed)
p_value = 2 * min(stats.f.cdf(F, df1, df2), 1 - stats.f.cdf(F, df1, df2))

print(f"Sample Variances: s1^2={s1_sq:.4f}, s2^2={s2_sq:.4f}")
print(f"F-statistic = {F:.4f}")
print(f"Critical region: F<{F_crit_low:.4f} or F>{F_crit_high:.4f}")
print(f"p-value = {p_value:.4f}")
print("Reject H0?", p_value < alpha)

# Visualization of F-distribution
x = np.linspace(0, 5, 500)
y = stats.f.pdf(x, df1, df2)

plt.figure(figsize=(8,5))
plt.plot(x, y, label="F-distribution")
plt.axvline(F, color='red', linestyle='--', label=f"F = {F:.2f}")
plt.axvline(F_crit_low, color='green', linestyle='--', label=f"Lower Crit = {F_crit_low:.2f}")
plt.axvline(F_crit_high, color='green', linestyle='--', label=f"Upper Crit = {F_crit_high:.2f}")
plt.fill_between(x, 0, y, where=(x < F_crit_low) | (x > F_crit_high), color='yellow', alpha=0.3, label='Rejection Region')
plt.title("F-Test for Comparing Two Variances")
plt.xlabel("F value")
plt.ylabel("Density")
plt.legend()
plt.show()
# Out:
# Sample Variances: s1^2=3.2381, s2^2=1.8095
# F-statistic = 1.7895
# Critical region: F<0.1718 or F>5.8198
# p-value = 0.4970
# Reject H0? False

# %%
# Q27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results?

# ANS.

import numpy as np
from scipy.stats import chisquare

# Simulated observed frequencies (e.g., 4 categories)
observed = np.array([25, 30, 20, 25])

# Expected frequencies (equal distribution assumption)
expected = np.array([25, 25, 25, 25])

print("Observed:", observed)
print("Expected:", expected)

# Perform Chi-square test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"Chi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀: The data does NOT fit the expected distribution.")
else:
    print("Fail to reject H₀: The data fits the expected distribution.")

import matplotlib.pyplot as plt

categories = ['Cat A', 'Cat B', 'Cat C', 'Cat D']

x = np.arange(len(categories))
width = 0.35

plt.bar(x - width/2, observed, width, label='Observed')
plt.bar(x + width/2, expected, width, label='Expected')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.title('Observed vs Expected Frequencies')
plt.xticks(x, categories)
plt.legend()
plt.show()
# Out:
# Observed: [25 30 20 25]
# Expected: [25 25 25 25]
# Chi-square Statistic: 2.0000
# P-value: 0.5724
# Fail to reject H₀: The data fits the expected distribution.
